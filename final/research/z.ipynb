# %%
import numpy as np
import pandas as pd
import plotly.express as px
filepath="dataset/pd.csv"
df=pd.read_csv(filepath,encoding_errors='ignore')
df.head()
# Out:
#    Age of the patient  Gender of the patient  Total Bilirubin  \
# 0            0.709302                    0.0         0.004021
# 1            0.674419                    0.5         0.140751
# 2            0.674419                    0.5         0.092493
# 3            0.627907                    0.5         0.008043
# 4            0.790698                    0.5         0.046917
#
#    Direct Bilirubin  Alkphos Alkaline Phosphotase  \
# 0          0.000000                      0.060576
# 1          0.275510                      0.310699
# 2          0.204082                      0.208598
# 3          0.015306                      0.058134
# 4          0.096939                      0.064485
#
#    Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                       0.003015                         0.001626
# 1                       0.027136                         0.018296
# 2                       0.025126                         0.011791
# ...

# %%
df['Result'].value_counts()
# Out:
# 0.0    13770
# 1.0    13770
# Name: Result, dtype: int64

# %%
column_name = 'Age of the patient'  # Replace with the actual column name

# Sort the DataFrame by the column in ascending order
df_sorted = df.sort_values(column_name)

# Create the Plotly figure
fig = px.histogram(df_sorted, x=column_name)
min_value = df_sorted[column_name].min()
max_value = df_sorted[column_name].max()

# Get the statistical measures
mean_value = df_sorted[column_name].mean()
std_value = df_sorted[column_name].std()
quantiles = df_sorted[column_name].quantile([0.25, 0.5, 0.75])
count = df_sorted[column_name].count()
print("Mean: {:.2f}".format(mean_value))
print("Std: {:.2f}".format(std_value))
print("Q1: {:.2f}".format(quantiles[0.25]))
print("Q2: {:.2f}".format(quantiles[0.5]))
print("Q3: {:.2f}".format(quantiles[0.75]))
print("Count: {}".format(count))
# Add annotations for statistical measures
fig.update_layout(
    annotations=[
         dict(
            x=min_value,
            y=0,
            xref="x",
            yref="paper",
            text="Min: {}".format(min_value),
            showarrow=True,
            arrowhead=1,
            ax=-40,
            ay=-40
        ),
        
        dict(
            x=max_value,
            y=0,
            xref="x",
            yref="paper",
            text="Max: {}".format(max_value),
            showarrow=True,
            arrowhead=1,
            ax=-40,
            ay=-40
        )
        
    ]
)

# Save the figure as an HTML file

# Show the plot
fig.show()
# Out:
# Mean: 0.46
# Std: 0.19
# Q1: 0.33
# Q2: 0.48
# Q3: 0.59
# Count: 27540

# %%
column_name = 'Result'  # Replace with the actual column name

# Sort the DataFrame by the column in ascending order
df_sorted = df.sort_values(column_name)

# Create the Plotly figure
fig = px.histogram(df_sorted, x=column_name)
min_value = df_sorted[column_name].min()
max_value = df_sorted[column_name].max()

# Get the statistical measures
mean_value = df_sorted[column_name].mean()
std_value = df_sorted[column_name].std()
quantiles = df_sorted[column_name].quantile([0.25, 0.5, 0.75])
count = df_sorted[column_name].count()
print("Mean: {:.2f}".format(mean_value))
print("Std: {:.2f}".format(std_value))
print("Q1: {:.2f}".format(quantiles[0.25]))
print("Q2: {:.2f}".format(quantiles[0.5]))
print("Q3: {:.2f}".format(quantiles[0.75]))
print("Count: {}".format(count))
# Add annotations for statistical measures
fig.update_layout(
    annotations=[
         dict(
            x=min_value,
            y=0,
            xref="x",
            yref="paper",
            text="Min: {}".format(min_value),
            showarrow=True,
            arrowhead=1,
            ax=-40,
            ay=-40
        ),
        
        dict(
            x=max_value,
            y=0,
            xref="x",
            yref="paper",
            text="Max: {}".format(max_value),
            showarrow=True,
            arrowhead=1,
            ax=-40,
            ay=-40
        )
        
    ]
)

# Save the figure as an HTML file

# Show the plot
fig.show()
# Out:
# Mean: 0.50
# Std: 0.50
# Q1: 0.00
# Q2: 0.50
# Q3: 1.00
# Count: 27540
